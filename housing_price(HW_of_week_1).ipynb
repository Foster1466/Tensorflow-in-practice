# %% [markdown]
# <a href="https://colab.research.google.com/github/Foster1466/Tensorflow-in-practice/blob/master/housing_price(HW_of_week_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
def house_model(y_new):
  xs= np.array([0, 1, 2, 3, 4, 5, 6], dtype= float)
  ys= np.array([0.5, 1, 1.5, 2, 2.5, 3, 3.5], dtype=float)
  model = keras.Sequential([keras.layers.Dense(units= 1, input_shape= [1])])
  model.compile(optimizer= 'sgd', loss= 'mean_squared_error')
  model.fit(xs,ys, epochs=500)
  return model.predict(y_new)[0]

# %%
prediction= house_model([7.0])
print(prediction)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 47.2580
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 24.8981
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 13.1180
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9118
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6421
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9195
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0120
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5339
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2820
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1493
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0793
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0425
# ...
